# %%
import xarray as xr
import numpy as np
import pandas as pd
import sys
sys.path.append('/home/563/rl5183/PhD-research/Functions')
import functions as func
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
# %store -r EP_regress_had
# %store -r CP_regress_had

# %%
# %store -r E_regress_had
# %store -r C_regress_had

# %%
fig = plt.figure(figsize = (15,3)) 
axs = []
ax = fig.add_subplot(221, projection=ccrs.PlateCarree(180))
im = EP_regress_had.plot(ax=ax, add_colorbar=False, transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_title('EP (NINO)')
axs.append(ax)
ax = fig.add_subplot(222, projection=ccrs.PlateCarree(180))
im = CP_regress_had.plot(ax=ax, add_colorbar=False, transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_title('CP (NINO)')
axs.append(ax)
ax = fig.add_subplot(223, projection=ccrs.PlateCarree(180))
im = E_regress_had.plot(ax=ax, add_colorbar=False, transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_title('EP (EOF)')
axs.append(ax)
ax = fig.add_subplot(224, projection=ccrs.PlateCarree(180))
im = C_regress_had.plot(ax=ax, add_colorbar=False, transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_title('CP (EOF)')
axs.append(ax)
cbar = plt.colorbar(im, ax=axs, shrink=0.75, pad=0.05)

plt.savefig('Poster Fig 1', bbox_inches='tight', dpi=300)

# %%
EP_regressions = xr.open_dataarray('/g/data/w40/rl5183/CMIP6_20_EP_temp_regressions')
CP_regressions = xr.open_dataarray('/g/data/w40/rl5183/CMIP6_20_CP_temp_regressions')
E_regressions = xr.open_dataarray('/g/data/w40/rl5183/CMIP6_20_E_temp_regressions')
C_regressions = xr.open_dataarray('/g/data/w40/rl5183/CMIP6_20_C_temp_regressions')

# %%
# %store -r EP_regress_20CR
# %store -r CP_regress_20CR
# %store -r E_regress_20CR
# %store -r C_regress_20CR

# %%
fig = plt.figure(figsize = (12,7.5)) 
axs = []
# EP NINO
ax = fig.add_subplot(431, projection=ccrs.PlateCarree(180))
im = EP_regress_20CR.plot(ax=ax, vmin=-1.5, vmax=1.5, cmap='RdBu_r', add_colorbar=False, transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_title('20CR')
axs.append(ax)
ax = fig.add_subplot(432, projection=ccrs.PlateCarree(180))
im = EP_regressions.sel(model='ACCESS-CM2').plot(ax=ax, vmin=-1.5, vmax=1.5, cmap='RdBu_r', add_colorbar=False, transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_title('ACCESS-CM2')
axs.append(ax)
ax = fig.add_subplot(433, projection=ccrs.PlateCarree(180))
im = EP_regressions.sel(model='GFDL-ESM4').plot(ax=ax, vmin=-1.5, vmax=1.5, cmap='RdBu_r', add_colorbar=False, transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_title('GFDL-ESM4')
axs.append(ax)

# EP EOF
ax = fig.add_subplot(434, projection=ccrs.PlateCarree(180))
im = E_regress_20CR.plot(ax=ax, vmin=-1.5, vmax=1.5, cmap='RdBu_r', add_colorbar=False, transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_title('')
axs.append(ax)
ax = fig.add_subplot(435, projection=ccrs.PlateCarree(180))
E = E_regressions.sel(model='ACCESS-CM2')*(-1)
im = E.plot(ax=ax, vmin=-1.5, vmax=1.5, cmap='RdBu_r', add_colorbar=False, transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_title('')
axs.append(ax)
ax = fig.add_subplot(436, projection=ccrs.PlateCarree(180))
E = E_regressions.sel(model='GFDL-ESM4')*(-1)
im = E.plot(ax=ax, vmin=-1.5, vmax=1.5, cmap='RdBu_r', add_colorbar=False, transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_title('')
axs.append(ax)

# CP NINO
ax = fig.add_subplot(437, projection=ccrs.PlateCarree(180))
im = CP_regress_20CR.plot(ax=ax, vmin=-1.5, vmax=1.5, cmap='RdBu_r', add_colorbar=False, transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_title('')
axs.append(ax)
ax = fig.add_subplot(438, projection=ccrs.PlateCarree(180))
im = CP_regressions.sel(model='ACCESS-CM2').plot(ax=ax, vmin=-1.5, vmax=1.5, cmap='RdBu_r', add_colorbar=False, transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_title('')
axs.append(ax)
ax = fig.add_subplot(439, projection=ccrs.PlateCarree(180))
im = CP_regressions.sel(model='GFDL-ESM4').plot(ax=ax, vmin=-1.5, vmax=1.5, cmap='RdBu_r', add_colorbar=False, transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_title('')
axs.append(ax)

# CP EOF
ax = fig.add_subplot(4,3,10, projection=ccrs.PlateCarree(180))
im = C_regress_20CR.plot(ax=ax, vmin=-1.5, vmax=1.5, cmap='RdBu_r', add_colorbar=False, transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_title('')
axs.append(ax)
ax = fig.add_subplot(4,3,11, projection=ccrs.PlateCarree(180))
C = C_regressions.sel(model='ACCESS-CM2')*(-1)
im = C.plot(ax=ax, vmin=-1.5, vmax=1.5, cmap='RdBu_r', add_colorbar=False, transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_title('')
axs.append(ax)
ax = fig.add_subplot(4,3,12, projection=ccrs.PlateCarree(180))
C = C_regressions.sel(model='GFDL-ESM4')*(-1)
im = C.plot(ax=ax, vmin=-1.5, vmax=1.5, cmap='RdBu_r', add_colorbar=False, transform=ccrs.PlateCarree())
ax.coastlines()
ax.set_title('')
axs.append(ax)

# Formatting 
cbar = plt.colorbar(im, ax=axs, shrink=0.5, pad=0.05)
#plt.savefig('Poster Fig 2 v2', bbox_inches='tight', dpi=300)

# %%
# %store -r EP_df
# %store -r CP_df

# %%
EP_df.boxplot(column=['Tropics', 'Sub Tropics NH', 'Sub Tropics SH', 'Mid Lats NH', 'Mid Lats SH'], figsize=(7.5,3.5))
plt.title('EP TEMP EOF')
plt.savefig('Poster Fig 3b', bbox_inches='tight', dpi=300)

# %%
CP_df.boxplot(column=['Tropics', 'Sub Tropics NH', 'Sub Tropics SH', 'Mid Lats NH', 'Mid Lats SH'], figsize=(7.5,3.5))
plt.title('CP TEMP EOF')
plt.savefig('Poster Fig 3d', bbox_inches='tight', dpi=300)

# %%
# %store -r EP_df
# %store -r CP_df

# %%
EP_df.boxplot(column=['Tropics', 'Sub Tropics NH', 'Sub Tropics SH', 'Mid Lats NH', 'Mid Lats SH'], figsize=(7.5,3.5))
plt.title('EP TEMP NINO')
plt.savefig('Poster Fig 3a', bbox_inches='tight', dpi=300)

# %%
CP_df.boxplot(column=['Tropics', 'Sub Tropics NH', 'Sub Tropics SH', 'Mid Lats NH', 'Mid Lats SH'], figsize=(7.5,3.5))
plt.title('CP TEMP NINO')
plt.savefig('Poster Fig 3c', bbox_inches='tight', dpi=300)
