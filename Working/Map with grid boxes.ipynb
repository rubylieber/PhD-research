# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

# %%
fig = plt.figure(figsize=(10,5))

ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()

plt.plot([139, 154], [-10, -10],
         color='red',
         transform=ccrs.PlateCarree(),
         )

plt.plot([139, 154], [-40, -40],
         color='red',
         transform=ccrs.PlateCarree(),
         )

plt.plot([139, 139], [-40, -10],
         color='red',
         transform=ccrs.PlateCarree(),
         )

plt.plot([154, 154], [-40, -10],
         color='red',
         transform=ccrs.PlateCarree(),
         )

plt.plot([20, 20], [-30, -20],
         color='red',
         transform=ccrs.PlateCarree(),
         )

plt.plot([30, 30], [-30, -20],
         color='red',
         transform=ccrs.PlateCarree(),
         )

plt.plot([20, 30], [-30, -30],
         color='red',
         transform=ccrs.PlateCarree(),
         )

plt.plot([20, 30], [-20, -20],
         color='red',
         transform=ccrs.PlateCarree(),
         )

plt.plot([280, 280], [-10, 10],
         color='red',
         transform=ccrs.PlateCarree(),
         )

plt.plot([310, 310], [-10, 10],
         color='red',
         transform=ccrs.PlateCarree(),
         )

plt.plot([280, 310], [-10, -10],
         color='red',
         transform=ccrs.PlateCarree(),
         )

plt.plot([280, 310], [10, 10],
         color='red',
         transform=ccrs.PlateCarree(),
         )

ax.set_global()

# plt.savefig('map_with_boxes.jpg', bbox_inches='tight', dpi=300, quality=80, optimize=True, progressive=True)
